# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import os

#load data from Data Wrangling

working_dir = os.getcwd()
print(working_dir)

train = pd.read_csv('../volcanic_data/train.csv')
data_train = pd.read_csv('../Capstone_Two_Data_Wrangling/data_train.csv')
data_train_scalar = pd.read_csv('../Capstone_Two_Data_Wrangling/data_train_scalar.csv')
data_train_scalar2 = pd.read_csv('../Capstone_Two_Data_Wrangling/data_train_scalar2.csv')
# Out:
# /Users/alvinqin/Springboard_ds/Springboard/Capstone_Two_EDA

# %%
data_train.head(10)
# Out:
#    segment_id  time_to_eruption  sensor_1_mean  sensor_1_std  sensor_1_min  \
# 0  1136037770          12262005      -1.610323    303.096099       -1421.0
# 1  1969647810          32739612       1.426126    438.360560       -2005.0
# 2  1895879680          14965999       2.504592    241.575415       -1115.0
# 3  2068207140          26469720       2.165797    221.967825       -1025.0
# 4   192955606          31072429       0.073815    261.695935       -1190.0
# 5  1640671020          22264866       5.765187    385.437067       -1637.0
# 6   288840453          34952168      -2.262362    365.011221       -2200.0
# 7  1162441568           9504818       1.099932    731.138523       -2999.0
# 8  1791400073          11719563      -1.085282    132.652571        -627.0
# 9  2059516238          11629084      -1.056799    334.039437       -1428.0
#
#    sensor_1_20  sensor_1_40  sensor_1_60  sensor_1_80  sensor_1_max  ...  \
# 0       -249.0        -72.0         72.0        249.0        1353.0  ...
# 1       -333.0        -96.0        100.0        338.0        2197.0  ...
# 2       -195.0        -58.0         58.0        199.0        1148.0  ...
# 3       -171.0        -50.0         52.0        177.0        1254.0  ...
# 4       -216.0        -63.0         62.0        212.0        1114.0  ...
# 5       -312.0        -95.0         96.0        322.0        2161.0  ...
# 6       -263.0        -76.0         76.0        259.0        2493.0  ...
# 7       -601.0       -181.0        184.0        612.0        3185.0  ...
# 8       -109.0        -31.0         32.0        107.0         555.0  ...
# 9       -278.0        -83.0         83.0        278.0        1368.0  ...
#
#    sensor_9_80  sensor_9_max  sensor_10_mean  sensor_10_std  sensor_10_min  \
# 0        306.0        2021.0        2.599440     596.865818        -3527.0
# 1        321.6        2189.0       19.895518     932.699662        -4591.0
# 2        199.0        1778.0        0.968101     500.544892        -2798.0
# 3        189.0        1340.0        8.381444     523.449843        -2911.0
# 4        212.0        7725.0       -3.740471     562.748316        -2611.0
# 5        277.0        1992.0       -0.476075     818.612428        -4050.0
# 6        284.0        2435.0        1.613540     743.664897        -4356.0
# 7        774.0        3769.0       13.847186    1173.415488        -4919.0
# 8        121.0         857.0       -1.708938     287.324096        -1538.0
# 9        334.0        1621.0       -5.659539     613.956330        -3195.0
#
#    sensor_10_20  sensor_10_40  sensor_10_60  sensor_10_80  sensor_10_max
# 0        -503.0        -151.0         159.0         507.0         2187.0
# 1        -692.0        -202.0         205.0         710.0         5319.0
# 2        -402.0        -121.0         120.0         403.0         2522.0
# 3        -400.0        -121.0         122.0         407.0         3614.0
# 4        -458.0        -134.0         134.0         449.0         3274.0
# 5        -670.0        -200.0         212.0         681.0         3980.0
# 6        -531.0        -158.0         160.0         538.0         5105.0
# 7        -952.0        -284.0         288.0         983.0         4576.0
# 8        -226.0         -67.0          69.0         226.0         1566.0
# 9        -500.0        -145.0         144.0         490.0         4109.0
#
# [10 rows x 82 columns]

# %%
data_train.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
print(data_train.head(),'\n\n')
print(data_train.describe(), "\n\n")
print(data_train.info(), "\n\n")
print(data_train.dtypes, '\n\n')
print(data_train.count(), '\n\n')
# Out:
#    segment_id  time_to_eruption  sensor_1_mean  sensor_1_std  sensor_1_min  \
# 0  1136037770          12262005      -1.610323    303.096099       -1421.0
# 1  1969647810          32739612       1.426126    438.360560       -2005.0
# 2  1895879680          14965999       2.504592    241.575415       -1115.0
# 3  2068207140          26469720       2.165797    221.967825       -1025.0
# 4   192955606          31072429       0.073815    261.695935       -1190.0
#
#    sensor_1_20  sensor_1_40  sensor_1_60  sensor_1_80  sensor_1_max  ...  \
# 0       -249.0        -72.0         72.0        249.0        1353.0  ...
# 1       -333.0        -96.0        100.0        338.0        2197.0  ...
# 2       -195.0        -58.0         58.0        199.0        1148.0  ...
# 3       -171.0        -50.0         52.0        177.0        1254.0  ...
# 4       -216.0        -63.0         62.0        212.0        1114.0  ...
#
#    sensor_9_80  sensor_9_max  sensor_10_mean  sensor_10_std  sensor_10_min  \
# 0        306.0        2021.0        2.599440     596.865818        -3527.0
# 1        321.6        2189.0       19.895518     932.699662        -4591.0
# 2        199.0        1778.0        0.968101     500.544892        -2798.0
# 3        189.0        1340.0        8.381444     523.449843        -2911.0
# 4        212.0        7725.0       -3.740471     562.748316        -2611.0
#
#    sensor_10_20  sensor_10_40  sensor_10_60  sensor_10_80  sensor_10_max
# 0        -503.0        -151.0         159.0         507.0         2187.0
# 1        -692.0        -202.0         205.0         710.0         5319.0
# 2        -402.0        -121.0         120.0         403.0         2522.0
# 3        -400.0        -121.0         122.0         407.0         3614.0
# 4        -458.0        -134.0         134.0         449.0         3274.0
#
# [5 rows x 82 columns]
#
#
#          segment_id  time_to_eruption  sensor_1_mean  sensor_1_std  \
# count  4.431000e+03      4.431000e+03    4431.000000   4431.000000
# mean   1.074694e+09      2.284891e+07      -0.524638    651.842101
# std    6.161966e+08      1.348439e+07      17.911542   1516.321117
# min    5.131810e+05      6.250000e+03    -595.472192      0.000000
# 25%    5.527934e+08      1.127016e+07      -1.788295    275.012918
# 50%    1.066153e+09      2.246559e+07       0.017700    361.358555
# 75%    1.606350e+09      3.434356e+07       1.826045    546.627936
# max    2.146939e+09      4.904609e+07     341.221530  21182.637579
#
#        sensor_1_min   sensor_1_20  sensor_1_40  sensor_1_60   sensor_1_80  \
# count   4431.000000   4431.000000  4431.000000  4431.000000   4431.000000
# mean   -3147.202663   -517.972783  -153.569849   153.458136    516.181268
# std     4831.281103   1298.842149   383.904517   385.162669   1290.717383
# min   -32767.000000 -21859.000000 -6347.000000     0.000000      0.000000
# 25%    -2748.000000   -435.500000  -129.000000    63.000000    215.000000
# 50%    -1970.000000   -286.000000   -84.000000    85.000000    286.000000
# 75%    -1389.500000   -216.000000   -63.000000   129.000000    437.500000
# max        0.000000      0.000000     0.000000  6410.000000  21640.000000
#
#        sensor_1_max  ...  sensor_9_80  sensor_9_max  sensor_10_mean  \
# count   4431.000000  ...   4431.00000   4431.000000     4431.000000
# mean    3183.427894  ...    524.43313   3104.505304       -0.362546
# std     4893.656332  ...   1356.70112   4878.327023       34.567683
# min        0.000000  ...      0.00000      0.000000    -1219.251543
# 25%     1402.000000  ...    211.00000   1465.000000       -3.330541
# 50%     1974.000000  ...    268.00000   2002.000000        0.097682
# 75%     2799.500000  ...    400.50000   2775.500000        3.804481
# max    32767.000000  ...  18152.00000  32767.000000     1022.320278
#
#        sensor_10_std  sensor_10_min  sensor_10_20  sensor_10_40  sensor_10_60  \
# count    4431.000000    4431.000000   4431.000000   4431.000000   4431.000000
# mean     1058.606440   -5248.341458   -839.564794   -249.027353    249.135003
# std      1816.124986    5208.346859   1617.070949    478.790828    481.223622
# min         0.000000  -32767.000000 -27068.000000  -8323.000000      0.000000
# 25%       581.878557   -5159.000000   -768.000000   -227.000000    129.000000
# 50%       723.271700   -4115.000000   -567.000000   -169.000000    168.000000
# 75%       979.230561   -3097.500000   -439.000000   -130.000000    228.000000
# max     23445.310398       0.000000      0.000000      0.000000   8918.000000
#
#        sensor_10_80  sensor_10_max
# count   4431.000000     4431.00000
# mean     839.474791     5228.43963
# std     1615.236085     5172.18309
# min        0.000000        0.00000
# 25%      438.000000     3111.00000
# 50%      568.000000     4074.00000
# 75%      772.000000     5161.00000
# max    26489.000000    32767.00000
#
# [8 rows x 82 columns]
#
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4431 entries, 0 to 4430
# Data columns (total 82 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   segment_id        4431 non-null   int64
#  1   time_to_eruption  4431 non-null   int64
#  2   sensor_1_mean     4431 non-null   float64
#  3   sensor_1_std      4431 non-null   float64
#  4   sensor_1_min      4431 non-null   float64
#  5   sensor_1_20       4431 non-null   float64
#  6   sensor_1_40       4431 non-null   float64
#  7   sensor_1_60       4431 non-null   float64
#  8   sensor_1_80       4431 non-null   float64
#  9   sensor_1_max      4431 non-null   float64
#  10  sensor_2_mean     4431 non-null   float64
#  11  sensor_2_std      4431 non-null   float64
#  12  sensor_2_min      4431 non-null   float64
#  13  sensor_2_20       4431 non-null   float64
#  14  sensor_2_40       4431 non-null   float64
#  15  sensor_2_60       4431 non-null   float64
#  16  sensor_2_80       4431 non-null   float64
#  17  sensor_2_max      4431 non-null   float64
#  18  sensor_3_mean     4431 non-null   float64
#  19  sensor_3_std      4431 non-null   float64
#  20  sensor_3_min      4431 non-null   float64
#  21  sensor_3_20       4431 non-null   float64
#  22  sensor_3_40       4431 non-null   float64
#  23  sensor_3_60       4431 non-null   float64
#  24  sensor_3_80       4431 non-null   float64
#  25  sensor_3_max      4431 non-null   float64
#  26  sensor_4_mean     4431 non-null   float64
#  27  sensor_4_std      4431 non-null   float64
#  28  sensor_4_min      4431 non-null   float64
#  29  sensor_4_20       4431 non-null   float64
#  30  sensor_4_40       4431 non-null   float64
#  31  sensor_4_60       4431 non-null   float64
#  32  sensor_4_80       4431 non-null   float64
#  33  sensor_4_max      4431 non-null   float64
#  34  sensor_5_mean     4431 non-null   float64
#  35  sensor_5_std      4431 non-null   float64
#  36  sensor_5_min      4431 non-null   float64
#  37  sensor_5_20       4431 non-null   float64
#  38  sensor_5_40       4431 non-null   float64
#  39  sensor_5_60       4431 non-null   float64
#  40  sensor_5_80       4431 non-null   float64
#  41  sensor_5_max      4431 non-null   float64
#  42  sensor_6_mean     4431 non-null   float64
#  43  sensor_6_std      4431 non-null   float64
#  44  sensor_6_min      4431 non-null   float64
#  45  sensor_6_20       4431 non-null   float64
#  46  sensor_6_40       4431 non-null   float64
#  47  sensor_6_60       4431 non-null   float64
#  48  sensor_6_80       4431 non-null   float64
#  49  sensor_6_max      4431 non-null   float64
#  50  sensor_7_mean     4431 non-null   float64
#  51  sensor_7_std      4431 non-null   float64
#  52  sensor_7_min      4431 non-null   float64
#  53  sensor_7_20       4431 non-null   float64
#  54  sensor_7_40       4431 non-null   float64
#  55  sensor_7_60       4431 non-null   float64
#  56  sensor_7_80       4431 non-null   float64
#  57  sensor_7_max      4431 non-null   float64
#  58  sensor_8_mean     4431 non-null   float64
#  59  sensor_8_std      4431 non-null   float64
#  60  sensor_8_min      4431 non-null   float64
#  61  sensor_8_20       4431 non-null   float64
#  62  sensor_8_40       4431 non-null   float64
#  63  sensor_8_60       4431 non-null   float64
#  64  sensor_8_80       4431 non-null   float64
#  65  sensor_8_max      4431 non-null   float64
#  66  sensor_9_mean     4431 non-null   float64
#  67  sensor_9_std      4431 non-null   float64
#  68  sensor_9_min      4431 non-null   float64
#  69  sensor_9_20       4431 non-null   float64
#  70  sensor_9_40       4431 non-null   float64
#  71  sensor_9_60       4431 non-null   float64
#  72  sensor_9_80       4431 non-null   float64
#  73  sensor_9_max      4431 non-null   float64
#  74  sensor_10_mean    4431 non-null   float64
#  75  sensor_10_std     4431 non-null   float64
#  76  sensor_10_min     4431 non-null   float64
#  77  sensor_10_20      4431 non-null   float64
#  78  sensor_10_40      4431 non-null   float64
#  79  sensor_10_60      4431 non-null   float64
#  80  sensor_10_80      4431 non-null   float64
#  81  sensor_10_max     4431 non-null   float64
# dtypes: float64(80), int64(2)
# memory usage: 2.8 MB
# None
#
#
# segment_id            int64
# time_to_eruption      int64
# sensor_1_mean       float64
# sensor_1_std        float64
# sensor_1_min        float64
#                      ...
# sensor_10_20        float64
# sensor_10_40        float64
# sensor_10_60        float64
# sensor_10_80        float64
# sensor_10_max       float64
# Length: 82, dtype: object
#
#
# segment_id          4431
# time_to_eruption    4431
# sensor_1_mean       4431
# sensor_1_std        4431
# sensor_1_min        4431
#                     ...
# sensor_10_20        4431
# sensor_10_40        4431
# sensor_10_60        4431
# sensor_10_80        4431
# sensor_10_max       4431
# Length: 82, dtype: int64

# %%
#Time to eruption distrubtion

plot = sns.distplot(data_train['time_to_eruption'], 
             hist=True, 
             kde=True, 
             bins=100, 
             color = 'red', 
             hist_kws={'edgecolor':'black'})
plot.set_title("The time until the next eruption", fontsize=12)
plot.set_xlabel("time_to_eruption", fontsize = 10)
plot.set_ylabel("density of train data", fontsize = 10)
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0, 0.5, 'density of train data')

# %%
#hexbin plot 

data_train.plot.hexbin(x= "segment_id",y ="time_to_eruption",gridsize=25, figsize = (10,10))
plt.show()

# %%
#check min max segmentid of time to eruption

display(train.sort_values('time_to_eruption', axis=0, ascending=True).iloc[[0,-1],:])
# Out:
#       segment_id  time_to_eruption
# 590    601524801              6250
# 1139  1923243961          49046087

# %%
segment_id_min =  601524801
segment_id_max = 1923243961

df_segment_id_min = pd.read_csv('../volcanic_data/train/'+str(segment_id_min)+'.csv')
df_segment_id_max = pd.read_csv('../volcanic_data/train/'+str(segment_id_max)+'.csv')

# %%
#ploting sensor data for min time to eruption

df_segment_id_min.plot(figsize=(20,20),
                       subplots=True, 
                       layout=(10,1),
                       rot=0, 
                       lw=1, 
                       title='segment_id #601524801 (min)'
                      )

plt.show()

# %%
#ploting sensor data for max time to eruption

df_segment_id_max.plot(figsize=(20,20),
                       subplots=True, 
                       layout=(10,1),
                       rot=0, 
                       lw=2, 
                       title='segment_id #1923243961 (max)'
                      )

plt.show()
